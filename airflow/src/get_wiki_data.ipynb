# %%
def get_wiki_page(url):
    import requests
    try:
        response = requests.get(url,timeout=10,verify=False)
        response.raise_for_status()
        
        return response.text
    except requests.RequestException as e:
        print(f"An error occured : {e}")

# %%
from bs4 import BeautifulSoup
html = get_wiki_page("https://en.wikipedia.org/wiki/List_of_association_football_stadiums_by_capacity")
soup = BeautifulSoup(html,features='html.parser')
table = soup.find_all("table",attrs={"class":"wikitable sortable sticky-header"})[0]

table_rows = table.find_all('tr')
# Out:
# C:\Users\A490629\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'en.wikipedia.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
class Stadium:
    def __init__(self, stadium=None, seating_cap=None, region=None, country=None, city=None, image_url=None, home_team=None, rank=None):
        self.stadium = stadium
        self.seating_cap = seating_cap
        self.region = region
        self.country = country
        self.city = city
        self.image_url = image_url
        self.home_team = home_team
        self.rank = rank

    def __repr__(self):
        return f"Stadium(stadium={self.stadium}, rank={self.rank})"

# %%
list_of_stadium=[] 
for i in range(1,len(table_rows)):
  cells = table_rows[i].find_all('td')
  stadium = Stadium(
  rank = i,
  stadium = cells[0].get_text().strip().replace('♦',''),
  seating_cap = cells[1].get_text().strip().split('[')[0].replace(',','') if '[' in cells[1].get_text() else cells[1].get_text().strip().replace(',',''),
  region = cells[2].get_text().strip(),
  country = cells[3].get_text().strip(),
  city = cells[4].get_text().strip(),
  image_url = cells[5].find('img')['src'] if cells[5].find('img') else 'No Image',
  home_team = cells[6].get_text().strip()
  )
  list_of_stadium.append(stadium)
list_of_stadium
# Out:
# [Stadium(stadium=Rungrado 1st of May Stadium , rank=1),
#  Stadium(stadium=Michigan Stadium, rank=2),
#  Stadium(stadium=Ohio Stadium, rank=3),
#  Stadium(stadium=Melbourne Cricket Ground , rank=4),
#  Stadium(stadium=Camp Nou , rank=5),
#  Stadium(stadium=Estadio Azteca , rank=6),
#  Stadium(stadium=FNB Stadium , rank=7),
#  Stadium(stadium=New Administrative Capital Stadium , rank=8),
#  Stadium(stadium=Rose Bowl Stadium, rank=9),
#  Stadium(stadium=Cotton Bowl Stadium, rank=10),
#  Stadium(stadium=Wembley Stadium , rank=11),
#  Stadium(stadium=Lusail Stadium , rank=12),
#  Stadium(stadium=Bukit Jalil National Stadium , rank=13),
#  Stadium(stadium=Borg el-Arab Stadium, rank=14),
#  Stadium(stadium=Estadio Santiago Bernabéu, rank=15),
#  Stadium(stadium=Estadio Mâs Monumental , rank=16),
#  Stadium(stadium=Stadium Australia, rank=17),
#  Stadium(stadium=MetLife Stadium, rank=18),
#  Stadium(stadium=Croke Park , rank=19),
#  Stadium(stadium=Jakarta International Stadium , rank=20),
#  Stadium(stadium=Lambeau Field, rank=21),
#  Stadium(stadium=Signal Iduna Park , rank=22),
#  Stadium(stadium=Stade de France , rank=23),
#  Stadium(stadium=Grand Sports Arena of the Luzhniki Olympic Complex , rank=24),
#  Stadium(stadium=Shah Alam Stadium, rank=25),
#  Stadium(stadium=Estadio Monumental , rank=26),
#  Stadium(stadium=Stadio Giuseppe Meazza , rank=27),
#  Stadium(stadium=Guangdong Olympic Stadium , rank=28),
#  Stadium(stadium=Hangzhou Olympic Sports Expo Centre Stadium, rank=29),
#  Stadium(stadium=AT&T Stadium , rank=30),
#  Stadium(stadium=Stade des Martyrs , rank=31),
#  Stadium(stadium=Stade Tata Raphaël , rank=32),
#  Stadium(stadium=National Sports Stadium , rank=33),
#  Stadium(stadium=Moi International Sports Centre , rank=34),
#  Stadium(stadium=Beijing National Stadium, rank=35),
#  Stadium(stadium=Stade Léopold Sédar Senghor , rank=36),
#  Stadium(stadium=Maracanã , rank=37),
#  Stadium(stadium=Los Angeles Memorial Coliseum, rank=38),
#  Stadium(stadium=Azadi Stadium , rank=39),
#  Stadium(stadium=Stadion Utama Gelora Bung Karno, rank=40),
#  Stadium(stadium=Caesar's Superdome, rank=41),
#  Stadium(stadium=Arrowhead Stadium, rank=42),
#  Stadium(stadium=Empower Field, rank=43),
#  Stadium(stadium=Atatürk Olimpiyat Stadyumu , rank=44),
#  Stadium(stadium=Old Trafford, rank=45),
#  Stadium(stadium=Allianz Arena, rank=46),
#  Stadium(stadium=Naghsh-e-Jahan Stadium, rank=47),
#  Stadium(stadium=Bank of America Stadium, rank=48),
#  Stadium(stadium=Principality Stadium , rank=49),
#  Stadium(stadium=Olympiastadion, rank=50),
#  Stadium(stadium=Cairo International Stadium, rank=51),
#  Stadium(stadium=FirstEnergy Stadium, rank=52),
#  Stadium(stadium=Estádio Nacional Mané Garrincha, rank=53),
#  Stadium(stadium=Stadio Olimpico, rank=54),
#  Stadium(stadium=Nissan Stadium , rank=55),
#  Stadium(stadium=NRG Stadium, rank=56),
#  Stadium(stadium=Shanghai Stadium, rank=57),
#  Stadium(stadium=M&T Bank Stadium, rank=58),
#  Stadium(stadium=Mercedes-Benz Stadium, rank=59),
#  Stadium(stadium=Cívitas Metropolitano, rank=60),
#  Stadium(stadium=Olympic National Sports Complex Stadium , rank=61),
#  Stadium(stadium=SoFi Stadium, rank=62),
#  Stadium(stadium=Seoul Olympic Stadium , rank=63),
#  Stadium(stadium=Bakı Olimpiya stadionu , rank=64),
#  Stadium(stadium=Olympic Stadium , rank=65),
#  Stadium(stadium=Olympiastadion München, rank=66),
#  Stadium(stadium=Lumen Field, rank=67),
#  Stadium(stadium=Estadio Olímpico Universitario, rank=68),
#  Stadium(stadium=Gillette Stadium, rank=69),
#  Stadium(stadium=King Abdullah Sports City Stadium , rank=70),
#  Stadium(stadium=Lincoln Financial Field, rank=71),
#  Stadium(stadium=Levi's Stadium, rank=72),
#  Stadium(stadium=Acrisure Stadium, rank=73),
#  Stadium(stadium=Gazprom Arena, rank=74),
#  Stadium(stadium=Salt Lake Stadium , rank=75),
#  Stadium(stadium=National Stadium, rank=76),
#  Stadium(stadium=TIAA Bank Field, rank=77),
#  Stadium(stadium=Orange Vélodrome, rank=78),
#  Stadium(stadium=Puskás Aréna , rank=79),
#  Stadium(stadium=Scottish Gas Murrayfield Stadium, rank=80),
#  Stadium(stadium=Lucas Oil Stadium, rank=81),
#  Stadium(stadium=MorumBIS, rank=82),
#  Stadium(stadium=The Dome, rank=83),
#  Stadium(stadium=Yadegar-e-Emam Stadium, rank=84),
#  Stadium(stadium=Seoul World Cup Stadium, rank=85),
#  Stadium(stadium=US Bank Stadium, rank=86),
#  Stadium(stadium=Daegu Stadium, rank=87),
#  Stadium(stadium=Workers' Stadium, rank=88),
#  Stadium(stadium=London Stadium, rank=89),
#  Stadium(stadium=Raymond James Stadium, rank=90),
#  Stadium(stadium=Hard Rock Stadium, rank=91),
#  Stadium(stadium=Olympic Stadium , rank=92),
#  Stadium(stadium=Basra International Stadium , rank=93),
#  Stadium(stadium=Camping World Stadium, rank=94),
#  Stadium(stadium=Alamodome, rank=95),
#  Stadium(stadium=Ford Field, rank=96),
#  Stadium(stadium=Stade Ibn Battuta, rank=97),
#  Stadium(stadium=Estádio do Sport Lisboa e Benfica , rank=98),
#  Stadium(stadium=Stade du 5-juillet-1962 , rank=99),
#  Stadium(stadium=Castelão, rank=100),
#  Stadium(stadium=Saitama Stadium 2002, rank=101),
#  Stadium(stadium=Ellis Park Stadium, rank=102),
#  Stadium(stadium=Tottenham Hotspur Stadium, rank=103),
#  Stadium(stadium=VELTINS-Arena, rank=104),
#  Stadium(stadium=Yizhong Sports Centre Stadium, rank=105),
#  Stadium(stadium=Estádio Governador Magalhães Pinto, rank=106),
#  Stadium(stadium=King Fahd International Stadium, rank=107),
#  Stadium(stadium=Soldier Field, rank=108),
#  Stadium(stadium=Nanjing Olympic Sports Centre Stadium, rank=109),
#  Stadium(stadium=Anfield, rank=110),
#  Stadium(stadium=Estadio Benito Villamarín, rank=111),
#  Stadium(stadium=Abuja Stadium , rank=112),
#  Stadium(stadium=MHPArena, rank=113),
#  Stadium(stadium=Celtic Park , rank=114),
#  Stadium(stadium=Estadio de la UNSA, rank=115),
#  Stadium(stadium=Emirates Stadium, rank=116),
#  Stadium(stadium=Shenzhen Universiade Sports Centre Stadium, rank=117),
#  Stadium(stadium=Estadio Centenario , rank=118),
#  Stadium(stadium=Estádio José do Rego Maciel, rank=119),
#  Stadium(stadium=Al-Bayt Stadium, rank=120),
#  Stadium(stadium=Benjamin Mkapa National Stadium , rank=121),
#  Stadium(stadium=Hefei Olympic Sports Centre Stadium, rank=122),
#  Stadium(stadium=Jaber al-Ahmad International Stadium , rank=123),
#  Stadium(stadium=Hammadi Agrebi Stadium , rank=124),
#  Stadium(stadium=Jawaharlal Nehru Stadium, rank=125),
#  Stadium(stadium=Mogadishu Stadium , rank=126),
#  Stadium(stadium=National Heroes Stadium , rank=127),
#  Stadium(stadium=Autzen Stadium, rank=128),
#  Stadium(stadium=Odi Stadium, rank=129),
#  Stadium(stadium=Morodok Techo National Stadium, rank=130),
#  Stadium(stadium=Shenyang Olympic Sports Centre Stadium, rank=131),
#  Stadium(stadium=Optus Stadium, rank=132),
#  Stadium(stadium=Estadio Monumental Isidro Romero Carbo , rank=133),
#  Stadium(stadium=Groupama Stadium, rank=134),
#  Stadium(stadium=Chongqing Olympic Sports Centre Stadium, rank=135),
#  Stadium(stadium=Kazimierz Górski National Stadium , rank=136),
#  Stadium(stadium=Stadio San Nicola, rank=137),
#  Stadium(stadium=Commanders Field, rank=138),
#  Stadium(stadium=Deutsche Bank Park, rank=139),
#  Stadium(stadium=Estadio La Cartuja de Sevilla, rank=140),
#  Stadium(stadium=Carter–Finley Stadium, rank=141),
#  Stadium(stadium=Estadio Alberto J. Armando, rank=142),
#  Stadium(stadium=Volksparkstadion, rank=143),
#  Stadium(stadium=Estadio Mario Alberto Kempes, rank=144),
#  Stadium(stadium=Jinan Olympic Sports Centre Stadium, rank=145),
#  Stadium(stadium=Estadio Jalisco, rank=146),
#  Stadium(stadium=Commonwealth Stadium, rank=147),
#  Stadium(stadium=Dodger Stadium, rank=148),
#  Stadium(stadium=Stade du 19-mai-1956, rank=149),
#  Stadium(stadium=Estadi Olímpic Lluís Companys, rank=150),
#  Stadium(stadium=Arena do Grêmio, rank=151),
#  Stadium(stadium=Arena Națională , rank=152),
#  Stadium(stadium=Stadion Rajko Mitić , rank=153),
#  Stadium(stadium=Stadion Śląski, rank=154),
#  Stadium(stadium=Etihad Stadium, rank=155),
#  Stadium(stadium=Mestalla, rank=156),
#  Stadium(stadium=National Stadium , rank=157),
#  Stadium(stadium=National Stadium , rank=158),
#  Stadium(stadium=He Long Stadium, rank=159),
#  Stadium(stadium=Cape Town Stadium, rank=160),
#  Stadium(stadium=Plovdiv Stadium , rank=161),
#  Stadium(stadium=Bobby Dodd Stadium, rank=162),
#  Stadium(stadium=Johan Cruijff Arena , rank=163),
#  Stadium(stadium=Tianhe Stadium, rank=164),
#  Stadium(stadium=Stadio Diego Armando Maradona, rank=165),
#  Stadium(stadium=Tianjin Olympic Sports Centre Stadium, rank=166),
#  Stadium(stadium=MERKUR SPIEL-ARENA, rank=167),
#  Stadium(stadium=Boris Paitchadze Dinamo Arena , rank=168),
#  Stadium(stadium=Wuhan Sports Centre Stadium, rank=169),
#  Stadium(stadium=BC Place Stadium, rank=170),
#  Stadium(stadium=Yankee Stadium, rank=171),
#  Stadium(stadium=Hrazdan Stadium , rank=172),
#  Stadium(stadium=BORUSSIA-PARK, rank=173),
#  Stadium(stadium=Moses Mabhida Stadium, rank=174),
#  Stadium(stadium=Busan Asiad Main Stadium, rank=175),
#  Stadium(stadium=Estádio Estadual Jornalista Edgar Augusto Proença, rank=176),
#  Stadium(stadium=Estadio Único Diego Armando Maradona, rank=177),
#  Stadium(stadium=Adelaide Oval, rank=178),
#  Stadium(stadium=Docklands Stadium, rank=179),
#  Stadium(stadium=Estádio Municipal João Havelange, rank=180),
#  Stadium(stadium=San Mamés, rank=181),
#  Stadium(stadium=Aleppo International Stadium , rank=182),
#  Stadium(stadium=Estadio Nacional, rank=183),
#  Stadium(stadium=Huanglong Stadium, rank=184),
#  Stadium(stadium=RAMS Park, rank=185),
#  Stadium(stadium=Suncorp Stadium, rank=186),
#  Stadium(stadium=St. James' Park, rank=187),
#  Stadium(stadium=Kings Park Stadium, rank=188),
#  Stadium(stadium=Newlands Stadium, rank=189),
#  Stadium(stadium=Hampden Park, rank=190),
#  Stadium(stadium=Estadio Monumental de Maturín , rank=191),
#  Stadium(stadium=Loftus Versfeld Stadium, rank=192),
#  Stadium(stadium=Aviva Stadium , rank=193),
#  Stadium(stadium=Guiyang Olympic Sports Centre Stadium, rank=194),
#  Stadium(stadium=Hohhot City Stadium, rank=195),
#  Stadium(stadium=Rajamangala National Stadium , rank=196),
#  Stadium(stadium=Donbass Arena, rank=197),
#  Stadium(stadium=Estadio Presidente Juan Domingo Perón, rank=198),
#  Stadium(stadium=İzmir Atatürk Stadyumu, rank=199),
#  Stadium(stadium=Stadion Feijenoord, rank=200),
#  Stadium(stadium=Estadio BBVA, rank=201),
#  Stadium(stadium=Ghadir Stadium, rank=202),
#  Stadium(stadium=Estádio José Pinheiro Borda, rank=203),
#  Stadium(stadium=Ibrox Stadium, rank=204),
#  Stadium(stadium=Shizuoka Stadium, rank=205),
#  Stadium(stadium=Ernst-Happel-Stadion , rank=206),
#  Stadium(stadium=Huntington Bank Stadium, rank=207),
#  Stadium(stadium=Estadio Cuauhtémoc, rank=208),
#  Stadium(stadium=Strawberry Arena , rank=209),
#  Stadium(stadium=Ülker Stadyumu, rank=210),
#  Stadium(stadium=Stanford Stadium, rank=211),
#  Stadium(stadium=Stade Pierre-Mauroy, rank=212),
#  Stadium(stadium=Stade Roi Baudouin , rank=213),
#  Stadium(stadium=Shaanxi Province Stadium, rank=214),
#  Stadium(stadium=Ajinomoto Stadium, rank=215),
#  Stadium(stadium=Estádio José Alvalade, rank=216),
#  Stadium(stadium=Estádio do Dragão, rank=217),
#  Stadium(stadium=Casa de Apostas Arena Fonte Nova, rank=218),
#  Stadium(stadium=Stade Olympique de Sousse, rank=219),
#  Stadium(stadium=RheinEnergieSTADION, rank=220),
#  Stadium(stadium=Harbin Sports City Centre Stadium, rank=221),
#  Stadium(stadium=Greenfield International Stadium, rank=222),
#  Stadium(stadium=EMS Stadium, rank=223),
#  Stadium(stadium=KD Singh Babu Stadium, rank=224),
#  Stadium(stadium=Eden Park , rank=225),
#  Stadium(stadium=Estádio 11 de Novembro , rank=226),
#  Stadium(stadium=Henan Provincial Stadium, rank=227),
#  Stadium(stadium=Jiangxi Olympic Sports Center, rank=228),
#  Stadium(stadium=Max-Morlock-Stadion, rank=229),
#  Stadium(stadium=June 11 Stadium , rank=230),
#  Stadium(stadium=Xinjiang Sports Centre Stadium, rank=231),
#  Stadium(stadium=Kim Il-sung Stadium, rank=232),
#  Stadium(stadium=EDION Stadium Hiroshima, rank=233),
#  Stadium(stadium=Pars Shiraz Stadium, rank=234),
#  Stadium(stadium=Stade du 26 mars , rank=235),
#  Stadium(stadium=Stade Abdoulaye Wade, rank=236),
#  Stadium(stadium=Sultan Mizan Zainal Abidin Stadium, rank=237),
#  Stadium(stadium=Estadio Akron, rank=238),
#  Stadium(stadium=Levy Mwanawasa Stadium, rank=239),
#  Stadium(stadium=Fritz-Walter-Stadion, rank=240),
#  Stadium(stadium=Estadio José Amalfitani, rank=241),
#  Stadium(stadium=Camille Chamoun Sports City Stadium , rank=242),
#  Stadium(stadium=Miyagi Stadium, rank=243),
#  Stadium(stadium=Incheon Munhak Stadium, rank=244),
#  Stadium(stadium=Heinz-von-Heiden-Arena, rank=245),
#  Stadium(stadium=Parc des Princes, rank=246),
#  Stadium(stadium=Stadium of Light, rank=247),
#  Stadium(stadium=Estadio Nacional , rank=248),
#  Stadium(stadium=Nelson Mandela Bay Stadium, rank=249),
#  Stadium(stadium=Estadio Tomás Adolfo Ducó, rank=250),
#  Stadium(stadium=Jinnah Sports Stadium , rank=251),
#  Stadium(stadium=Estadio Libertadores de América, rank=252),
#  Stadium(stadium=Free State Stadium, rank=253),
#  Stadium(stadium=Nagai Stadium, rank=254),
#  Stadium(stadium=Neo Química Arena, rank=255),
#  Stadium(stadium=Rogers Centre, rank=256),
#  Stadium(stadium=Estadio Monumental, rank=257),
#  Stadium(stadium=Stadio Artemio Franchi, rank=258),
#  Stadium(stadium=Estadio Ciudad de Lanús – Néstor Díaz Pérez, rank=259),
#  Stadium(stadium=Estadio Metropolitano Roberto Meléndez, rank=260),
#  Stadium(stadium=Estádio Olímpico Nilton Santos, rank=261),
#  Stadium(stadium=Itaipava Arena Pernambuco, rank=262),
#  Stadium(stadium=Arena MRV, rank=263),
#  Stadium(stadium=Estádio Paulo Constantino, rank=264),
#  Stadium(stadium=Estadio Atanasio Girardot, rank=265),
#  Stadium(stadium=Estadio Ramón Sánchez Pizjuán, rank=266),
#  Stadium(stadium=Adrar Stadium, rank=267),
#  Stadium(stadium=Lukoil Arena, rank=268),
#  Stadium(stadium=Grand stade de Marrakech, rank=269),
#  Stadium(stadium=Mandela National Stadium , rank=270),
#  Stadium(stadium=Tarczyński Arena Wrocław, rank=271),
#  Stadium(stadium=Kazan Arena, rank=272),
#  Stadium(stadium=Estadio Inca Garcilaso de la Vega, rank=273),
#  Stadium(stadium=Estádio da Machava , rank=274),
#  Stadium(stadium=Stadion Gelora Bung Tomo, rank=275),
#  Stadium(stadium=Stadion Harapan Banga, rank=276),
#  Stadium(stadium=Estadio General Pablo Rojas , rank=277),
#  Stadium(stadium=Stade Mohammed V , rank=278),
#  Stadium(stadium=Latakia Sports City Stadium, rank=279),
#  Stadium(stadium=Zibo Sports Centre Stadium, rank=280),
#  Stadium(stadium=Weifang Sports Centre Stadium, rank=281),
#  Stadium(stadium=Yantai Sports Park Stadium, rank=282),
#  Stadium(stadium=Stadium Tuanku Abdul Rahman, rank=283),
#  Stadium(stadium=Stade du Complexe sportif de Fès, rank=284),
#  Stadium(stadium=Lagos National Stadium, rank=285),
#  Stadium(stadium=Egyptian Army Stadium, rank=286),
#  Stadium(stadium=Toyota Stadium, rank=287),
#  Stadium(stadium=Zayed Sports City Stadium, rank=288),
#  Stadium(stadium=Red Bull Arena, rank=289),
#  Stadium(stadium=Estádio Governador Alberto Tavares Silva, rank=290),
#  Stadium(stadium=Estádio Universitário Pedro Pedrossian, rank=291),
#  Stadium(stadium=Ulsan Munsu Football Stadium, rank=292),
#  Stadium(stadium=Arena Pantanal, rank=293),
#  Stadium(stadium=Arena da Amazônia, rank=294),
#  Stadium(stadium=Suwon World Cup Stadium, rank=295),
#  Stadium(stadium=Stadion Utama Riau, rank=296),
#  Stadium(stadium=Allianz Parque, rank=297),
#  Stadium(stadium=Shandong Provincial Stadium, rank=298),
#  Stadium(stadium=Polsat Plus Arena Gdańsk, rank=299),
#  Stadium(stadium=Estadio Pedro Bidegain, rank=300),
#  Stadium(stadium=Stadion Miejski w Poznaniu, rank=301),
#  Stadium(stadium=Vasil Levski National Stadium, rank=302),
#  Stadium(stadium=Estadio Universidad San Marcos, rank=303),
#  Stadium(stadium=Ullevi, rank=304),
#  Stadium(stadium=Jinzhou Binhai Sports Centre Stadium, rank=305),
#  Stadium(stadium=Estadio General Santander, rank=306),
#  Stadium(stadium=Villa Park, rank=307),
#  Stadium(stadium=Perak Stadium, rank=308),
#  Stadium(stadium=Jeonju World Cup Stadium, rank=309),
#  Stadium(stadium=Ligga Arena, rank=310),
#  Stadium(stadium=Weserstadion, rank=311),
#  Stadium(stadium=Denka Big Swan Stadium, rank=312),
#  Stadium(stadium=Estadio Olimpico Metropolitano de Mérida, rank=313),
#  Stadium(stadium=Daejeon World Cup Stadium, rank=314),
#  Stadium(stadium=Matmut ATLANTIQUE, rank=315),
#  Stadium(stadium=Helsingin Olympiastadion , rank=316),
#  Stadium(stadium=Estádio Serra Dourada, rank=317),
#  Stadium(stadium=Estadio Deportivo Cali , rank=318),
#  Stadium(stadium=Estadio Modelo Alberto Spencer, rank=319),
#  Stadium(stadium=Estádio do Zimpeto, rank=320),
#  Stadium(stadium=Chengdu Sports Centre Stadium, rank=321),
#  Stadium(stadium=Royal Bafokeng Stadium, rank=322),
#  Stadium(stadium=Estadio Universitario, rank=323),
#  Stadium(stadium=Estadio Brigadier General Estanislao López, rank=324),
#  Stadium(stadium=Estadio Marcelo Bielsa, rank=325),
#  Stadium(stadium=Stade Geoffroy-Guichard, rank=326),
#  Stadium(stadium=Vodafone Park, rank=327),
#  Stadium(stadium=Peter Mokaba Stadium, rank=328),
#  Stadium(stadium=Estadio Gigante de Arroyito, rank=329),
#  Stadium(stadium=Estadio Cachamay, rank=330),
#  Stadium(stadium=Estadio de Liga Deportiva Universitaria, rank=331),
#  Stadium(stadium=Allianz Stadium, rank=332),
#  Stadium(stadium=Sapporo Dome, rank=333),
#  Stadium(stadium=Stamford Bridge, rank=334),
#  Stadium(stadium=Goyang Stadium, rank=335),
#  Stadium(stadium=Estadio Hernando Siles , rank=336),
#  Stadium(stadium=Bingu National Stadium, rank=337),
#  Stadium(stadium=Mbombela Stadium, rank=338),
#  Stadium(stadium=Estadio José Pachencho Romero, rank=339),
#  Stadium(stadium=Stade Nelson Mandela, rank=340),
#  Stadium(stadium=Kashima Football Stadium, rank=341),
#  Stadium(stadium=Baba Yara Stadium , rank=342),
#  Stadium(stadium=Estádio Major Antônio Couto Pereira, rank=343),
#  Stadium(stadium=Stage Front Stadium, rank=344),
#  Stadium(stadium=Estadio Metropolitano de fútbol de Lara, rank=345),
#  Stadium(stadium=Estadio Malvinas Argentinas, rank=346),
#  Stadium(stadium=Stadion Lukas Enembe, rank=347),
#  Stadium(stadium=Gwangju World Cup Stadium, rank=348),
#  Stadium(stadium=Sân vận động Quốc gia Mỹ Đình , rank=349),
#  Stadium(stadium=Goodison Park, rank=350),
#  Stadium(stadium=Estádio Governador João Castelo, rank=351),
#  Stadium(stadium=Stade Miloud-Hadefi, rank=352),
#  Stadium(stadium=Estadio Campeón del Siglo, rank=353),
#  Stadium(stadium=Metalist Stadium, rank=354),
#  Stadium(stadium=Al-Janoub Stadium, rank=355),
#  Stadium(stadium=Al-Thumama Stadium, rank=356),
#  Stadium(stadium=Stade Ahmed-Zabana, rank=357),
#  Stadium(stadium=Stadion Batakan, rank=358),
#  Stadium(stadium=Stadion Gelora Joko Samudro, rank=359),
#  Stadium(stadium=Fisht Olympic Stadium, rank=360),
#  Stadium(stadium=Rentschler Field, rank=361),
#  Stadium(stadium=Jawaharlal Nehru Stadium, rank=362),
#  Stadium(stadium=Hang Jebat Stadium, rank=363),
#  Stadium(stadium=Hong Kong Stadium , rank=364),
#  Stadium(stadium=Stadium Negeri Pulau Pinang, rank=365),
#  Stadium(stadium=Accra Sports Stadium, rank=366),
#  Stadium(stadium=Sarawak Stadium, rank=367),
#  Stadium(stadium=Bogyoke Aung San Stadium , rank=368),
#  Stadium(stadium=Resonac Dome Ōita, rank=369),
#  Stadium(stadium=Stadium Darul Makmur, rank=370),
#  Stadium(stadium=Khalifa International Stadium, rank=371),
#  Stadium(stadium=Stade de l’Amitié sino-gabonaise , rank=372),
#  Stadium(stadium=Peoples Football Stadium, rank=373),
#  Stadium(stadium=JRD Tata Sports Complex Stadium, rank=374),
#  Stadium(stadium=Bao'an Stadium, rank=375),
#  Stadium(stadium=Kunming Tuodong Sports Centre Stadium, rank=376),
#  Stadium(stadium=Taizhou Sports Centre Stadium, rank=377),
#  Stadium(stadium=Wuhu Olympic Stadium, rank=378),
#  Stadium(stadium=Huizhou Olympic Stadium, rank=379)]

# %%
import pandas as pd
# Convert list of stadium objects to DataFrame
data = {
    'Rank': [s.rank for s in list_of_stadium],
    'Stadium': [s.stadium for s in list_of_stadium],
    'Seating Capacity': [s.seating_cap for s in list_of_stadium],
    'Region': [s.region for s in list_of_stadium],
    'Country': [s.country for s in list_of_stadium],
    'City': [s.city for s in list_of_stadium],
    'Image URL': [s.image_url for s in list_of_stadium],
    'Home Team': [s.home_team for s in list_of_stadium]
}
list_of_stadium_df = pd.DataFrame(data)
# Out:
#    Rank  ...                                          Home Team
# 0     1  ...  Korea DPR national football team, Korea DPR wo...
# 1     2  ...                       Michigan Wolverines football
# 2     3  ...                       Ohio State Buckeyes football
# 3     4  ...  Australia national cricket team, Victoria cric...
# 4     5  ...                                       FC Barcelona
#
# [5 rows x 8 columns]

# %%
list_of_stadium_df.to_csv('list_of_stadium.csv',index=False)

# %%
cells = table_rows[1].find_all('td')

# %%
stadium_name = cells[0].get_text().strip().replace('♦','')
stadium_name
# Out:
# 'Rungrado 1st of May Stadium '

# %%
seating_cap = cells[1].get_text().strip().split('[')[0].replace(',','') if '[' in cells[1].get_text() else cells[1].get_text().strip().replace(',','') 
seating_cap
# Out:
# '40000'

# %%
region = cells[2].get_text().strip()
region
# Out:
# 'East Asia'

# %%
country = cells[3].get_text().strip()
country
# Out:
# 'North Korea'

# %%
city = cells[4].get_text().strip()
city
# Out:
# 'Pyongyang'

# %%
image_url = cells[5].find('img')['src'] if cells[5] is not None else 'No Image'
image_url
# Out:
# '//upload.wikimedia.org/wikipedia/commons/thumb/8/81/Arirang_Mass_Games_12.JPG/150px-Arirang_Mass_Games_12.JPG'

# %%
home_team = cells[6].get_text().strip()
home_team
# Out:
# "Korea DPR national football team, Korea DPR women's national football team, April 25"
